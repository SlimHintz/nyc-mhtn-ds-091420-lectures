# %% [markdown]
# # JSON and APIs
#
# _September 22, 2020_
#
# Agenda today:
# - Introduction to API and Remote Server Model
# - Getting data through an API: Case study with YELP API

# %%
API KEY = '2MtMQg6kyoJUYLcZgr_fZ86mbTvobbsPXy3S045Ge0-fgtu3-0UCJfrEkL6mZ48X5HYtcEXqWlj6mVTuCDl0ZIayQefEgYdvQd_TIBg283BENLFvTOQ-HbmKkw1qX3Yx'

ID = '5FV6d79g5IFRDRnAWjah_g'

# %% [markdown]
# def lookup():
#     """Look up quote for symbol."""
#
#     # Contact API
#     try:
#         api_key = os.environ.get("API_KEY")
#         response = requests.get(f"https://cloud-sse.iexapis.com/stable/stock/{urllib.parse.quote_plus(symbol)}/quote?token={api_key}")
#         response.raise_for_status()
#     except requests.RequestException:
#         return None

# %%
import pandas as pd
import numpy as np
import requests
import os
import json
from yelp.client import Client
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
# Git ignore. 

# Always use pd for data cleaning

# %% [markdown]
# ## Part I. APIs and Remote Server Model
# API stands for Application Programming Interface. At some point or the other, large companies would build API for their products for their clients or internal use. It allows the company's application to communicate with another application. But what _exactly_ is an API?
#
# #### Remote server
# When we think about the world of Web, we can think of it as a collection of _servers_. And servers are nothing but huge computers that store a huge amount of data from users and are optimized to process requests. For example, when you type in www.facebook.com, your browser sends a _request_ to the Facebook server, and gets a response from the server, thus interpreting the code and displaying your homepage.
#
# In this case, your browser is the _client_, and Facebook’s server is an API. To put it broadly, whenever you visit a website, you are interacting with its API. However, an API isn’t the same as the remote server — rather it is the part of the server that receives __requests__ and sends __responses__.
#
# <img src='status-code.png' width = 500>

# %% [markdown]
# ## Part II. Getting Data Through APIs
#
# The `get()` method send a request to YELP's API, and stored information in a variable called `request`. Next, let's see if it's successful.

# %% [markdown]
# #### YELP API
# Sometimes you need _authentication_ to get data from a service in additional to just sending a `GET()` request. Yelp API is a perfect example.
#
# You will need to go to the YELP's developer's [website](https://www.yelp.com/developers/v3/manage_app) and request for a client ID and API key, which function like a key into a house of data.
#
# <img src='yelp.png' width = 500>

# %%
# lets try to get some data from yelp!
url = 'https://api.yelp.com/v3/businesses/search'
response = requests.get(url)

# %%
# check the status code
response.status_code

# what happened here?
# Out:
# 400

# %%
# now we are ready to get our data 

# usually, services would limit you to a certain amount of API calls. This varies from service
# to service, so you have to watch out to it 

MY_API_KEY = '2MtMQg6kyoJUYLcZgr_fZ86mbTvobbsPXy3S045Ge0-fgtu3-0UCJfrEkL6mZ48X5HYtcEXqWlj6mVTuCDl0ZIayQefEgYdvQd_TIBg283BENLFvTOQ-HbmKkw1qX3Yx'



term = 'Axe Throwing'
location = 'Brooklyn'
SEARCH_LIMIT = 30

url = 'https://api.yelp.com/v3/businesses/search'

# Key goes into the headers parameter of the .get method.
headers = {
        'Authorization': 'Bearer {}'.format(MY_API_KEY),
    }

url_params = {
                'term': term.replace(' ', '+'), # The search terms should be joined by a "+"
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
response = requests.get(url, headers=headers, params=url_params)

# %%
# examine the response object

print(response)
# Out:
# <Response [200]>

# %%
# how are we going to parse the response.text object?

print(response.text)
# Out:
# {"businesses": [{"id": "X0DNGKUQPjf0AfaXfXU2Qg", "alias": "kick-axe-throwing-brooklyn-2", "name": "Kick Axe Throwing", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/WjKylwrUBKnGIE_ldj142Q/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/kick-axe-throwing-brooklyn-2?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g", "review_count": 399, "categories": [{"alias": "bars", "title": "Bars"}, {"alias": "axethrowing", "title": "Axe Throwing"}, {"alias": "tradamerican", "title": "American (Traditional)"}], "rating": 4.5, "coordinates": {"latitude": 40.6790268, "longitude": -73.983077}, "transactions": [], "location": {"address1": "622 Degraw St", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11217", "country": "US", "state": "NY", "display_address": ["622 Degraw St", "Brooklyn, NY 11217"]}, "phone": "+18335425293", "display_phone": "(833) 542-5293", "distance": 4733.616620254917}, {"id": "4E6BkrEVf_0TjRVYE7gxeQ", "alias": "bury-the-hatchet-brooklyn-axe-throwing-brooklyn-2", "name": "Bury the Hatchet Brooklyn - Axe Throwing", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/SH8_Nwmd13LkntwuzcEPeg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/bury-the-hatchet-brooklyn-axe-throwing-brooklyn-2?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g", "review_count": 143, "categories": [{"alias": "axethrowing", "title": "Axe Throwing"}, {"alias": "teambuilding", "title": "Team Building Activities"}], "rating": 4.5, "coordinates": {"latitude": 40.7283195, "longitude": -73.9600679}, "transactions": [], "location": {"address1": "25 Noble St", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11222", "country": "US", "state": "NY", "display_address": ["25 Noble St", "Brooklyn, NY 11222"]}, "phone": "+19172439696", "display_phone": "(917) 243-9696", "distance": 8652.979400045351}, {"id": "PhEkSzYZHKYS7uyXePmkMw", "alias": "axes-and-arrows-long-island-city-2", "name": "Axes And Arrows", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/Uinh_osn8ykDeLoigmgo0Q/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/axes-and-arrows-long-island-city-2?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g", "review_count": 49, "categories": [{"alias": "axethrowing", "title": "Axe Throwing"}, {"alias": "archery", "title": "Archery"}], "rating": 4.5, "coordinates": {"latitude": 40.7425127, "longitude": -73.933816}, "transactions": [], "location": {"address1": "47- 11 Van Dam St", "address2": null, "address3": "", "city": "Long Island City", "zip_code": "11101", "country": "US", "state": "NY", "display_address": ["47- 11 Van Dam St", "Long Island City, NY 11101"]}, "phone": "+17183619152", "display_phone": "(718) 361-9152", "distance": 9996.588059135383}, {"id": "lZVE27r_W_3GXxNwECYC4g", "alias": "live-axe-new-york", "name": "Live Axe", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-Z1qvni_2N-K85FHmaesaQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/live-axe-new-york?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g", "review_count": 2, "categories": [{"alias": "axethrowing", "title": "Axe Throwing"}, {"alias": "bars", "title": "Bars"}], "rating": 5.0, "coordinates": {"latitude": 40.71769, "longitude": -74.00144}, "transactions": [], "location": {"address1": "96 Lafayette St", "address2": null, "address3": null, "city": "New York", "zip_code": "10013", "country": "US", "state": "NY", "display_address": ["96 Lafayette St", "New York, NY 10013"]}, "phone": "+18888129060", "display_phone": "(888) 812-9060", "distance": 8955.976101576549}, {"id": "b9DAbR-1eIfLr6TPI_r59Q", "alias": "axe-kicking-entertainment-mineola", "name": "Axe Kicking ...

# %%
# working with JSON

axe_throwing = response.text
axe_throwing = json.loads(axe_throwing)

# %%
# json.load() loads a json file
# json.loads(s) parses a json like string into a dict

# %%
# cleaning and exploring the data
for key in axe_throwing.keys():
    print(key)
# Out:
# businesses
# total
# region

# %%
axe_throwing
# Out:
# {'businesses': [{'id': 'X0DNGKUQPjf0AfaXfXU2Qg',
#    'alias': 'kick-axe-throwing-brooklyn-2',
#    'name': 'Kick Axe Throwing',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WjKylwrUBKnGIE_ldj142Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kick-axe-throwing-brooklyn-2?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g',
#    'review_count': 399,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'axethrowing', 'title': 'Axe Throwing'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6790268, 'longitude': -73.983077},
#    'transactions': [],
#    'location': {'address1': '622 Degraw St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['622 Degraw St', 'Brooklyn, NY 11217']},
#    'phone': '+18335425293',
#    'display_phone': '(833) 542-5293',
#    'distance': 4733.616620254917},
#   {'id': '4E6BkrEVf_0TjRVYE7gxeQ',
#    'alias': 'bury-the-hatchet-brooklyn-axe-throwing-brooklyn-2',
#    'name': 'Bury the Hatchet Brooklyn - Axe Throwing',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SH8_Nwmd13LkntwuzcEPeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bury-the-hatchet-brooklyn-axe-throwing-brooklyn-2?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g',
#    'review_count': 143,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'},
#     {'alias': 'teambuilding', 'title': 'Team Building Activities'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7283195, 'longitude': -73.9600679},
#    'transactions': [],
#    'location': {'address1': '25 Noble St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Noble St', 'Brooklyn, NY 11222']},
#    'phone': '+19172439696',
#    'display_phone': '(917) 243-9696',
#    'distance': 8652.979400045351},
#   {'id': 'PhEkSzYZHKYS7uyXePmkMw',
#    'alias': 'axes-and-arrows-long-island-city-2',
#    'name': 'Axes And Arrows',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Uinh_osn8ykDeLoigmgo0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/axes-and-arrows-long-island-city-2?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g',
#    'review_count': 49,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'},
#     {'alias': 'archery', 'title': 'Archery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7425127, 'longitude': -73.933816},
#    'transactions': [],
#    'location': {'address1': '47- 11 Van Dam St',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47- 11 Van Dam St', 'Long Island City, NY 11101']},
#    'phone': '+17183619152',
#    'display_phone': '(718) 361-9152',
#    'distance': 9996.588059135383},
#   {'id': 'lZVE27r_W_3GXxNwECYC4g',
#    'alias': 'live-axe-new-york',
#    'name': 'Live Axe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-Z1qvni_2N-K85FHmaesaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/live-axe-new-york?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g',
#    'review_count': 2,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71769, 'longitude': -74.00144},
#    'transactions': [],
#    'location': {'address1': '96 Lafayette St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['96 Lafayette St', 'New York, NY 10013']},
#    'phone': '+18888129060',
#    'display_phone': '(888) 812-9060',
#    'distance': 8955.976101576549},
#   {'id': 'b9DAbR-1eIfLr6TPI_r59Q',
#    'alias': 'axe-kicking-entertainment-mineola',
#    'name': 'Axe Kicking Entertainment',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/stIBBatr6P1t9IKtZpL2Lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/axe-kicking-entertainment-mineola?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g',
#    'review_count': 2,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'},
#     {'alias': 'archery', 'title': 'Archery'},
#     {'alias': 'bowling', 'title': 'Bowling'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74638, 'longitude': -73.65027},
#    'transactions': [],
#    'location': {'address1': '360 Jericho Turnpike',
#     'address2': None,
#     'address3': '',
#     'city': 'Mineola',
#     'zip_code': '11501',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['360 Jericho Turnpike', 'Mineola, NY 11501']},
#    'phone': '+15162806040',
#    'display_phone': '(516) 280-6040',
#    'distance': 26518.825160012875},
#   {'id': 'K_Jm8V-XuOFlbHb_VUzk-w',
#    'alias': 'indoor-extreme-sports-long-island-city',
#    'name': 'Indoor Extreme Sports',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wQE-gOKf-shCB4sDI2WmhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/indoor-extreme-sports-long-island-city?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g',
#    'review_count': 508,
#    'categories': [{'alias': 'paintball', 'title': 'Paintball'},
#     {'alias': 'lasertag', 'title': 'Laser Tag'},
#     {'alias': 'axethrowing', 'title': 'Axe Throwing'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7422746, 'longitude': -73.9338804},
#    'transactions': [],
#    'location': {'address1': '47 11 Van Dam St',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 11 Van Dam St', 'Long Island City, NY 11101']},
#    'phone': '+17183619152',
#    'display_phone': '(718) 361-9152',
#    'distance': 10012.024588128},
#   {'id': 'yXOjBSwyqOKDY7oHx3z7HA',
#    'alias': 'tomahawks-jersey-city',
#    'name': 'Tomahawks',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AcR-ExIWOWPNXRr6G5cGQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tomahawks-jersey-city?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g',
#    'review_count': 13,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7411216, 'longitude': -74.0493572},
#    'transactions': [],
#    'location': {'address1': '7 Sherman Ave',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07307',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['7 Sherman Ave', 'Fl 2', 'Jersey City, NJ 07307']},
#    'phone': '+12014209722',
#    'display_phone': '(201) 420-9722',
#    'distance': 13556.0314007906},
#   {'id': 'wuy6jyi5cxm1pwnUTWyBLw',
#    'alias': 'stumpys-hatchet-house-fairfield-fairfield-3',
#    'name': "Stumpy's Hatchet House Fairfield - Axe Throwing",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yKG858jIoenW0jLpq6Hg1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stumpys-hatchet-house-fairfield-fairfield-3?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g',
#    'review_count': 44,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'},
#     {'alias': 'recreation', 'title': 'Recreation Centers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.8824525201793,
#     'longitude': -74.2942046508915},
#    'transactions': [],
#    'location': {'address1': '373 Us-46 W',
#     'address2': 'Ste D140',
#     'address3': '',
#     'city': 'Fairfield',
#     'zip_code': '07004',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['373 Us-46 W', 'Ste D140', 'Fairfield, NJ 07004']},
#    'phone': '+19737213120',
#    'display_phone': '(973) 721-3120',
#    'distance': 39341.674681213146},
#   {'id': '1BUoVTCYSpGfG0oobAr5Hg',
#    'alias': 'bury-the-hatchet-axe-throwing-bloomfield-bloomfield',
#    'name': 'Bury The Hatchet Axe Throwing- Bloomfield',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Y6OdaWjNZKFNKuSdl-rU3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bury-the-hatchet-axe-throwing-bloomfield-bloomfield?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g',
#    'review_count': 90,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.79607, 'longitude': -74.2003299},
#    'transactions': [],
#    'location': {'address1': '672 Bloomfield Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Bloomfield',
#     'zip_code': '07003',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['672 Bloomfield Ave', 'Bloomfield, NJ 07003']},
#    'phone': '+19738427725',
#    'display_phone': '(973) 842-7725',
#    'distance': 27173.957270887662},
#   {'id': 'oKkn9nKh6jB-fsQIDbP4tQ',
#    'alias': 'bury-the-hatchet-matawan',
#    'name': 'Bury The Hatchet',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EsKEUTyvjjzdr6SzTzubSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bury-the-hatchet-matawan?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g',
#    'review_count': 88,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'},
#     {'alias': 'teambuilding', 'title': 'Team Building Activities'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.4234040521118,
#     'longitude': -74.2643531039357},
#    'transactions': [],
#    'location': {'address1': '419 Route 34',
#     'address2': '',
#     'address3': None,
#     'city': 'Matawan',
#     'zip_code': '07747',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['419 Route 34', 'Matawan, NJ 07747']},
#    'phone': '+17329626284',
#    'display_phone': '(732) 962-6284',
#    'distance': 37446.224760844736},
#   {'id': 'xC9gtq17G9XU5d-yjkprfA',
#    'alias': 'bury-the-hatchet-paramus-axe-throwing-paramus-2',
#    'name': 'Bury the Hatchet Paramus - Axe Throwing',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2z7jvctXJEeKUBKB-XIPSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bury-the-hatchet-paramus-axe-throwing-paramus-2?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g',
#    'review_count': 75,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.94936, 'longitude': -74.068},
#    'transactions': [],
#    'location': {'address1': '49 E Midland Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Paramus',
#     'zip_code': '07652',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['49 E Midland Ave', 'Paramus, NJ 07652']},
#    'phone': '+12016883358',
#    'display_phone': '(201) 688-3358',
#    'distance': 34723.273827788835},
#   {'id': '35-KOEjrEy1wtSLqXwwv2A',
#    'alias': 'alpha-axe-throwing-long-beach',
#    'name': 'Alpha Axe Throwing',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/83LywQI2svJXqAAfo1hE_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alpha-axe-throwing-long-beach?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g',
#    'review_count': 1,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.5884373, 'longitude': -73.657908},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Beach',
#     'zip_code': '11561',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Long Beach, NY 11561']},
#    'phone': '+15162060999',
#    'display_phone': '(516) 206-0999',
#    'distance': 24794.675520636432},
#   {'id': '5izrkxTF_OWgwEdgzjNCAA',
#    'alias': 'bury-the-hatchet-woodbridge-axe-throwing-avenel',
#    'name': 'Bury The Hatchet Woodbridge - Axe Throwing',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZhVxhmy3BDOGaEwflbF9RA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bury-the-hatchet-woodbridge-axe-throwing-avenel?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g',
#    'review_count': 6,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.5919, 'longitude': -74.28943},
#    'transactions': [],
#    'location': {'address1': '1600 St Georges Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Avenel',
#     'zip_code': '07001',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1600 St Georges Ave', 'Avenel, NJ 07001']},
#    'phone': '+17322986614',
#    'display_phone': '(732) 298-6614',
#    'distance': 30246.00489811494},
#   {'id': 'BOYnPH11OTCMPzxiPJXHpw',
#    'alias': 'hatchet-house-hackensack-3',
#    'name': 'Hatchet House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1BayJ29kv-F92Dqy7uboDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hatchet-house-hackensack-3?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g',
#    'review_count': 1,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'paintball', 'title': 'Paintball'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.8832357904038,
#     'longitude': -74.0432552620768},
#    'transactions': [],
#    'location': {'address1': '157A Main St',
#     'address2': '',
#     'address3': None,
#     'city': 'Hackensack',
#     'zip_code': '07601',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['157A Main St', 'Hackensack, NJ 07601']},
#    'phone': '+18332934653',
#    'display_phone': '(833) 293-4653',
#    'distance': 27125.32070094518},
#   {'id': 'LN1itZNPsylqInDsLG4M_g',
#    'alias': 'new-york-sports-clubs-new-york-73',
#    'name': 'New York Sports Clubs',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eMLTokizDk84J50jB3gmzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-new-york-73?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g',
#    'review_count': 108,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'},
#     {'alias': 'sports_clubs', 'title': 'Sports Clubs'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.7455891, 'longitude': -73.9980521},
#    'transactions': [],
#    'location': {'address1': '270 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['270 8th Ave', 'New York, NY 10011']},
#    'phone': '+12122433400',
#    'display_phone': '(212) 243-3400',
#    'distance': 11489.778200039469},
#   {'id': '0OJWRkAI-iot-dtKX6BjbQ',
#    'alias': 'queens-archery-flushing',
#    'name': 'Queens Archery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lXOzZPUHPPdu8iGsaH38nA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/queens-archery-flushing?adjust_creative=5FV6d79g5IFRDRnAWjah_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5FV6d79g5IFRDRnAWjah_g',
#    'review_count': 362,
#    'categories': [{'alias': 'sports_clubs', 'title': 'Sports Clubs'},
#     {'alias': 'archery', 'title': 'Archery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76137, 'longitude': -73.79556},
#    'transactions': [],
#    'location': {'address1': '170-20 39th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11358',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['170-20 39th Ave', 'Flushing, NY 11358']},
#    'phone': '+17184611756',
#    'display_phone': '(718) 461-1756',
#    'distance': 17134.395523061943}],
#  'total': 28,
#  'region': {'center': {'longitude': -73.93936157226562,
#    'latitude': 40.652330148320374}}}

# %%
axe_throwing['businesses'][0]['id']
# Out:
# 'X0DNGKUQPjf0AfaXfXU2Qg'

# %%
# turn the relevant dataset into a dataframe




# with open ("axe_throwing.json", 'w') as json_file:

#     json.dump(axe_throwing, json_file)

# df = pd.read_json()

# %%
axe_throwing_df = pd.DataFrame.from_dict(axe_throwing['businesses'])
axe_throwing_df.set_index('id')
# Out:
#                                                                     alias  \
# id
# X0DNGKUQPjf0AfaXfXU2Qg                       kick-axe-throwing-brooklyn-2
# 4E6BkrEVf_0TjRVYE7gxeQ  bury-the-hatchet-brooklyn-axe-throwing-brooklyn-2
# PhEkSzYZHKYS7uyXePmkMw                 axes-and-arrows-long-island-city-2
# lZVE27r_W_3GXxNwECYC4g                                  live-axe-new-york
# b9DAbR-1eIfLr6TPI_r59Q                  axe-kicking-entertainment-mineola
# K_Jm8V-XuOFlbHb_VUzk-w             indoor-extreme-sports-long-island-city
# yXOjBSwyqOKDY7oHx3z7HA                              tomahawks-jersey-city
# wuy6jyi5cxm1pwnUTWyBLw        stumpys-hatchet-house-fairfield-fairfield-3
# 1BUoVTCYSpGfG0oobAr5Hg  bury-the-hatchet-axe-throwing-bloomfield-bloom...
# oKkn9nKh6jB-fsQIDbP4tQ                           bury-the-hatchet-matawan
# xC9gtq17G9XU5d-yjkprfA    bury-the-hatchet-paramus-axe-throwing-paramus-2
# 35-KOEjrEy1wtSLqXwwv2A                      alpha-axe-throwing-long-beach
# 5izrkxTF_OWgwEdgzjNCAA    bury-the-hatchet-woodbridge-axe-throwing-avenel
# BOYnPH11OTCMPzxiPJXHpw                         hatchet-house-hackensack-3
# LN1itZNPsylqInDsLG4M_g                  new-york-sports-clubs-new-york-73
# 0OJWRkAI-iot-dtKX6BjbQ                            queens-archery-flushing
#
#                                                                    name  \
# id
# X0DNGKUQPjf0AfaXfXU2Qg                                Kick Axe Throwing
# 4E6BkrEVf_0TjRVYE7gxeQ         Bury the Hatchet Brooklyn - Axe Throwing
# PhEkSzYZHKYS7uyXePmkMw                                  Axes And Arrows
# lZVE27r_W_3GXxNwECYC4g                                         Live Axe
# b9DAbR-1eIfLr6TPI_r59Q                        Axe Kicking Entertainment
# K_Jm8V-XuOFlbHb_VUzk-w                            Indoor Extreme Sports
# yXOjBSwyqOKDY7oHx3z7HA                                        Tomahawks
# wuy6jyi5cxm1pwnUTWyBLw  Stumpy's Hatchet House Fairfield - Axe Throwing
# 1BUoVTCYSpGfG0oobAr5Hg        Bury The Hatchet Axe Throwing- Bloomfield
# oKkn9nKh6jB-fsQIDbP4tQ                                 Bury The Hatchet
# xC9gtq17G9XU5d-yjkprfA          Bury the Hatchet Paramus - Axe Throwing
# 35-KOEjrEy1wtSLqXwwv2A                               Alpha Axe Throwing
# 5izrkxTF_OWgwEdgzjNCAA       Bury The Hatchet Woodbridge - Axe Throwing
# BOYnPH11OTCMPzxiPJXHpw                                    Hatchet House
# LN1itZNPsylqInDsLG4M_g                            New York Sports Clubs
# 0OJWRkAI-iot-dtKX6BjbQ                                   Queens Archery
#
#                                                                 image_url  \
# id
# X0DNGKUQPjf0AfaXfXU2Qg  https://s3-media1.fl.yelpcdn.com/bphoto/WjKylw...
# 4E6BkrEVf_0TjRVYE7gxeQ  https://s3-media3.fl.yelpcdn.com/bphoto/SH8_Nw...
# PhEkSzYZHKYS7uyXePmkMw  https://s3-media4.fl.yelpcdn.com/bphoto/Uinh_o...
# lZVE27r_W_3GXxNwECYC4g  https://s3-media2.fl.yelpcdn.com/bphoto/-Z1qvn...
# b9DAbR-1eIfLr6TPI_r59Q  https://s3-media3.fl.yelpcdn.com/bphoto/stIBBa...
# K_Jm8V-XuOFlbHb_VUzk-w  https://s3-media2.fl.yelpcdn.com/bphoto/wQE-gO...
# yXOjBSwyqOKDY7oHx3z7HA  https://s3-media1.fl.yelpcdn.com/bphoto/AcR-Ex...
# wuy6jyi5cxm1pwnUTWyBLw  https://s3-media1.fl.yelpcdn.com/bphoto/yKG858...
# 1BUoVTCYSpGfG0oobAr5Hg  https://s3-media2.fl.yelpcdn.com/bphoto/Y6OdaW...
# oKkn9nKh6jB-fsQIDbP4tQ  https://s3-media1.fl.yelpcdn.com/bphoto/EsKEUT...
# xC9gtq17G9XU5d-yjkprfA  https://s3-media4.fl.yelpcdn.com/bphoto/2z7jvc...
# 35-KOEjrEy1wtSLqXwwv2A  https://s3-media1.fl.yelpcdn.com/bphoto/83LywQ...
# 5izrkxTF_OWgwEdgzjNCAA  https://s3-media2.fl.yelpcdn.com/bphoto/ZhVxhm...
# BOYnPH11OTCMPzxiPJXHpw  https://s3-media3.fl.yelpcdn.com/bphoto/1BayJ2...
# LN1itZNPsylqInDsLG4M_g  https://s3-media2.fl.yelpcdn.com/bphoto/eMLTok...
# 0OJWRkAI-iot-dtKX6BjbQ  https://s3-media3.fl.yelpcdn.com/bphoto/lXOzZP...
#
#                         is_closed  \
# id
# X0DNGKUQPjf0AfaXfXU2Qg      False
# 4E6BkrEVf_0TjRVYE7gxeQ      False
# PhEkSzYZHKYS7uyXePmkMw      False
# lZVE27r_W_3GXxNwECYC4g      False
# b9DAbR-1eIfLr6TPI_r59Q      False
# K_Jm8V-XuOFlbHb_VUzk-w      False
# yXOjBSwyqOKDY7oHx3z7HA      False
# wuy6jyi5cxm1pwnUTWyBLw      False
# 1BUoVTCYSpGfG0oobAr5Hg      False
# oKkn9nKh6jB-fsQIDbP4tQ      False
# xC9gtq17G9XU5d-yjkprfA      False
# 35-KOEjrEy1wtSLqXwwv2A      False
# 5izrkxTF_OWgwEdgzjNCAA      False
# BOYnPH11OTCMPzxiPJXHpw      False
# LN1itZNPsylqInDsLG4M_g      False
# 0OJWRkAI-iot-dtKX6BjbQ      False
#
#                                                                       url  \
# id
# X0DNGKUQPjf0AfaXfXU2Qg  https://www.yelp.com/biz/kick-axe-throwing-bro...
# 4E6BkrEVf_0TjRVYE7gxeQ  https://www.yelp.com/biz/bury-the-hatchet-broo...
# PhEkSzYZHKYS7uyXePmkMw  https://www.yelp.com/biz/axes-and-arrows-long-...
# lZVE27r_W_3GXxNwECYC4g  https://www.yelp.com/biz/live-axe-new-york?adj...
# b9DAbR-1eIfLr6TPI_r59Q  https://www.yelp.com/biz/axe-kicking-entertain...
# K_Jm8V-XuOFlbHb_VUzk-w  https://www.yelp.com/biz/indoor-extreme-sports...
# yXOjBSwyqOKDY7oHx3z7HA  https://www.yelp.com/biz/tomahawks-jersey-city...
# wuy6jyi5cxm1pwnUTWyBLw  https://www.yelp.com/biz/stumpys-hatchet-house...
# 1BUoVTCYSpGfG0oobAr5Hg  https://www.yelp.com/biz/bury-the-hatchet-axe-...
# oKkn9nKh6jB-fsQIDbP4tQ  https://www.yelp.com/biz/bury-the-hatchet-mata...
# xC9gtq17G9XU5d-yjkprfA  https://www.yelp.com/biz/bury-the-hatchet-para...
# 35-KOEjrEy1wtSLqXwwv2A  https://www.yelp.com/biz/alpha-axe-throwing-lo...
# 5izrkxTF_OWgwEdgzjNCAA  https://www.yelp.com/biz/bury-the-hatchet-wood...
# BOYnPH11OTCMPzxiPJXHpw  https://www.yelp.com/biz/hatchet-house-hackens...
# LN1itZNPsylqInDsLG4M_g  https://www.yelp.com/biz/new-york-sports-clubs...
# 0OJWRkAI-iot-dtKX6BjbQ  https://www.yelp.com/biz/queens-archery-flushi...
#
#                         review_count  \
# id
# X0DNGKUQPjf0AfaXfXU2Qg           399
# 4E6BkrEVf_0TjRVYE7gxeQ           143
# PhEkSzYZHKYS7uyXePmkMw            49
# lZVE27r_W_3GXxNwECYC4g             2
# b9DAbR-1eIfLr6TPI_r59Q             2
# K_Jm8V-XuOFlbHb_VUzk-w           508
# yXOjBSwyqOKDY7oHx3z7HA            13
# wuy6jyi5cxm1pwnUTWyBLw            44
# 1BUoVTCYSpGfG0oobAr5Hg            90
# oKkn9nKh6jB-fsQIDbP4tQ            88
# xC9gtq17G9XU5d-yjkprfA            75
# 35-KOEjrEy1wtSLqXwwv2A             1
# 5izrkxTF_OWgwEdgzjNCAA             6
# BOYnPH11OTCMPzxiPJXHpw             1
# LN1itZNPsylqInDsLG4M_g           108
# 0OJWRkAI-iot-dtKX6BjbQ           362
#
#                                                                categories  \
# id
# X0DNGKUQPjf0AfaXfXU2Qg  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 4E6BkrEVf_0TjRVYE7gxeQ  [{'alias': 'axethrowing', 'title': 'Axe Throwi...
# PhEkSzYZHKYS7uyXePmkMw  [{'alias': 'axethrowing', 'title': 'Axe Throwi...
# lZVE27r_W_3GXxNwECYC4g  [{'alias': 'axethrowing', 'title': 'Axe Throwi...
# b9DAbR-1eIfLr6TPI_r59Q  [{'alias': 'axethrowing', 'title': 'Axe Throwi...
# K_Jm8V-XuOFlbHb_VUzk-w  [{'alias': 'paintball', 'title': 'Paintball'},...
# yXOjBSwyqOKDY7oHx3z7HA  [{'alias': 'axethrowing', 'title': 'Axe Throwi...
# wuy6jyi5cxm1pwnUTWyBLw  [{'alias': 'axethrowing', 'title': 'Axe Throwi...
# 1BUoVTCYSpGfG0oobAr5Hg  [{'alias': 'axethrowing', 'title': 'Axe Throwi...
# oKkn9nKh6jB-fsQIDbP4tQ  [{'alias': 'axethrowing', 'title': 'Axe Throwi...
# xC9gtq17G9XU5d-yjkprfA  [{'alias': 'axethrowing', 'title': 'Axe Throwi...
# 35-KOEjrEy1wtSLqXwwv2A  [{'alias': 'axethrowing', 'title': 'Axe Throwi...
# 5izrkxTF_OWgwEdgzjNCAA  [{'alias': 'axethrowing', 'title': 'Axe Throwi...
# BOYnPH11OTCMPzxiPJXHpw  [{'alias': 'axethrowing', 'title': 'Axe Throwi...
# LN1itZNPsylqInDsLG4M_g  [{'alias': 'gyms', 'title': 'Gyms'}, {'alias':...
# 0OJWRkAI-iot-dtKX6BjbQ  [{'alias': 'sports_clubs', 'title': 'Sports Cl...
#
#                         rating  \
# id
# X0DNGKUQPjf0AfaXfXU2Qg     4.5
# 4E6BkrEVf_0TjRVYE7gxeQ     4.5
# PhEkSzYZHKYS7uyXePmkMw     4.5
# lZVE27r_W_3GXxNwECYC4g     5.0
# b9DAbR-1eIfLr6TPI_r59Q     5.0
# K_Jm8V-XuOFlbHb_VUzk-w     4.0
# yXOjBSwyqOKDY7oHx3z7HA     4.5
# wuy6jyi5cxm1pwnUTWyBLw     5.0
# 1BUoVTCYSpGfG0oobAr5Hg     4.5
# oKkn9nKh6jB-fsQIDbP4tQ     5.0
# xC9gtq17G9XU5d-yjkprfA     4.0
# 35-KOEjrEy1wtSLqXwwv2A     5.0
# 5izrkxTF_OWgwEdgzjNCAA     4.5
# BOYnPH11OTCMPzxiPJXHpw     3.0
# LN1itZNPsylqInDsLG4M_g     2.0
# 0OJWRkAI-iot-dtKX6BjbQ     4.5
#
#                                                               coordinates  \
# id
# X0DNGKUQPjf0AfaXfXU2Qg  {'latitude': 40.6790268, 'longitude': -73.983077}
# 4E6BkrEVf_0TjRVYE7gxeQ  {'latitude': 40.7283195, 'longitude': -73.9600...
# PhEkSzYZHKYS7uyXePmkMw  {'latitude': 40.7425127, 'longitude': -73.933816}
# lZVE27r_W_3GXxNwECYC4g     {'latitude': 40.71769, 'longitude': -74.00144}
# b9DAbR-1eIfLr6TPI_r59Q     {'latitude': 40.74638, 'longitude': -73.65027}
# K_Jm8V-XuOFlbHb_VUzk-w  {'latitude': 40.7422746, 'longitude': -73.9338...
# yXOjBSwyqOKDY7oHx3z7HA  {'latitude': 40.7411216, 'longitude': -74.0493...
# wuy6jyi5cxm1pwnUTWyBLw  {'latitude': 40.8824525201793, 'longitude': -7...
# 1BUoVTCYSpGfG0oobAr5Hg   {'latitude': 40.79607, 'longitude': -74.2003299}
# oKkn9nKh6jB-fsQIDbP4tQ  {'latitude': 40.4234040521118, 'longitude': -7...
# xC9gtq17G9XU5d-yjkprfA       {'latitude': 40.94936, 'longitude': -74.068}
# 35-KOEjrEy1wtSLqXwwv2A  {'latitude': 40.5884373, 'longitude': -73.657908}
# 5izrkxTF_OWgwEdgzjNCAA      {'latitude': 40.5919, 'longitude': -74.28943}
# BOYnPH11OTCMPzxiPJXHpw  {'latitude': 40.8832357904038, 'longitude': -7...
# LN1itZNPsylqInDsLG4M_g  {'latitude': 40.7455891, 'longitude': -73.9980...
# 0OJWRkAI-iot-dtKX6BjbQ     {'latitude': 40.76137, 'longitude': -73.79556}
#
#                        transactions  \
# id
# X0DNGKUQPjf0AfaXfXU2Qg           []
# 4E6BkrEVf_0TjRVYE7gxeQ           []
# PhEkSzYZHKYS7uyXePmkMw           []
# lZVE27r_W_3GXxNwECYC4g           []
# b9DAbR-1eIfLr6TPI_r59Q           []
# K_Jm8V-XuOFlbHb_VUzk-w           []
# yXOjBSwyqOKDY7oHx3z7HA           []
# wuy6jyi5cxm1pwnUTWyBLw           []
# 1BUoVTCYSpGfG0oobAr5Hg           []
# oKkn9nKh6jB-fsQIDbP4tQ           []
# xC9gtq17G9XU5d-yjkprfA           []
# 35-KOEjrEy1wtSLqXwwv2A           []
# 5izrkxTF_OWgwEdgzjNCAA           []
# BOYnPH11OTCMPzxiPJXHpw           []
# LN1itZNPsylqInDsLG4M_g           []
# 0OJWRkAI-iot-dtKX6BjbQ           []
#
#                                                                  location  \
# id
# X0DNGKUQPjf0AfaXfXU2Qg  {'address1': '622 Degraw St', 'address2': None...
# 4E6BkrEVf_0TjRVYE7gxeQ  {'address1': '25 Noble St', 'address2': None, ...
# PhEkSzYZHKYS7uyXePmkMw  {'address1': '47- 11 Van Dam St', 'address2': ...
# lZVE27r_W_3GXxNwECYC4g  {'address1': '96 Lafayette St', 'address2': No...
# b9DAbR-1eIfLr6TPI_r59Q  {'address1': '360 Jericho Turnpike', 'address2...
# K_Jm8V-XuOFlbHb_VUzk-w  {'address1': '47 11 Van Dam St', 'address2': N...
# yXOjBSwyqOKDY7oHx3z7HA  {'address1': '7 Sherman Ave', 'address2': 'Fl ...
# wuy6jyi5cxm1pwnUTWyBLw  {'address1': '373 Us-46 W', 'address2': 'Ste D...
# 1BUoVTCYSpGfG0oobAr5Hg  {'address1': '672 Bloomfield Ave', 'address2':...
# oKkn9nKh6jB-fsQIDbP4tQ  {'address1': '419 Route 34', 'address2': '', '...
# xC9gtq17G9XU5d-yjkprfA  {'address1': '49 E Midland Ave', 'address2': N...
# 35-KOEjrEy1wtSLqXwwv2A  {'address1': '', 'address2': None, 'address3':...
# 5izrkxTF_OWgwEdgzjNCAA  {'address1': '1600 St Georges Ave', 'address2'...
# BOYnPH11OTCMPzxiPJXHpw  {'address1': '157A Main St', 'address2': '', '...
# LN1itZNPsylqInDsLG4M_g  {'address1': '270 8th Ave', 'address2': '', 'a...
# 0OJWRkAI-iot-dtKX6BjbQ  {'address1': '170-20 39th Ave', 'address2': ''...
#
#                                phone   display_phone      distance
# id
# X0DNGKUQPjf0AfaXfXU2Qg  +18335425293  (833) 542-5293   4733.616620
# 4E6BkrEVf_0TjRVYE7gxeQ  +19172439696  (917) 243-9696   8652.979400
# PhEkSzYZHKYS7uyXePmkMw  +17183619152  (718) 361-9152   9996.588059
# lZVE27r_W_3GXxNwECYC4g  +18888129060  (888) 812-9060   8955.976102
# b9DAbR-1eIfLr6TPI_r59Q  +15162806040  (516) 280-6040  26518.825160
# K_Jm8V-XuOFlbHb_VUzk-w  +17183619152  (718) 361-9152  10012.024588
# yXOjBSwyqOKDY7oHx3z7HA  +12014209722  (201) 420-9722  13556.031401
# wuy6jyi5cxm1pwnUTWyBLw  +19737213120  (973) 721-3120  39341.674681
# 1BUoVTCYSpGfG0oobAr5Hg  +19738427725  (973) 842-7725  27173.957271
# oKkn9nKh6jB-fsQIDbP4tQ  +17329626284  (732) 962-6284  37446.224761
# xC9gtq17G9XU5d-yjkprfA  +12016883358  (201) 688-3358  34723.273828
# 35-KOEjrEy1wtSLqXwwv2A  +15162060999  (516) 206-0999  24794.675521
# 5izrkxTF_OWgwEdgzjNCAA  +17322986614  (732) 298-6614  30246.004898
# BOYnPH11OTCMPzxiPJXHpw  +18332934653  (833) 293-4653  27125.320701
# LN1itZNPsylqInDsLG4M_g  +12122433400  (212) 243-3400  11489.778200
# 0OJWRkAI-iot-dtKX6BjbQ  +17184611756  (718) 461-1756  17134.395523

# %%
# you can do some analysis and visualization from here on! 


# visualize the review count - what's the appropriate plot?

# %%
# query the name of the axe throwing place with the highest review

# %%
# migrate the cleaned data into a sql db

# %%
# can you do some other queries using sql/pandas?

# %% [markdown]
# #### Resources
# - [Getting Data from Reddit API](https://www.storybench.org/how-to-scrape-reddit-with-python/)
# - [Twitch API](https://dev.twitch.tv/docs)
