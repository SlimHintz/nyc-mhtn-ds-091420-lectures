# %% [markdown]
# ## Data Comprehension
#
# - Decide whether the target is cont or categorical
#
# - what does row represent?
#
# - Comprehend all of the feature
#
#
#
#
# ## Data Cleaning
# - Missing Values
#      - no missing values
#
# - Data Types
#      - all floats and ints, no objects
#
# - Outliers
#     -
#
# - Duplicates
#
# - Check for data integrity
#
#
# ## Data Preparation
#
# - Drop 'unnamed' column
#
# - replace white space in column names
#
# - check for imbalance
#
#
# ## EDA
#
# - pair plots of every variable against every other variable to potentially create additional variables.
#     - categorize variables to see if distributions clump in specvific ways
#         - bin them
#
#     - look at scatterplots of cont variables
#         - look for groupings to bin into categorical variables
#
#         - if ther are trends we can create additional variabels that specify the relaionship
#             - if exponenital, take the log etc
#
#
#
#
# ## Modeling
#
# - split into train / test sets
#
# - Pick Classification models to run
#     - logisitc regression
#     - knn
#
# - Run cross validation initial models for each of the models and see how they do.
#     - run cross_val on X_train and y_train to generate mean recall accross different folds
#     - fit X_train
#     - generate predictions on test and train
#     - generate metrics for predictions against actual values
#          - maximise recall because we want to select a model that minimises type II errors
#     - generate both training and testing metrics through cross-validation we will look for over and underfitting
#
#
# ## Final analysis interpretation
